# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/DeepLearningProject2025_Commit/DeepLearningProject-2025'

# 1. Colab Secrets에서 GitHub PAT를 가져옵니다.
# Colab 왼쪽 패널의 자물쇠 아이콘(비밀)에서 'GITHUB_TOKEN'이라는 이름으로 PAT를 저장했다고 가정합니다.
from google.colab import userdata

# 'GITHUB_TOKEN'은 Colab Secrets에 저장된 PAT의 이름입니다.
# 실제 PAT 값을 직접 코드에 입력하지 마세요.
GITHUB_PAT = userdata.get('GITHUB_TOKEN')

# 2. Git 원격 저장소 URL을 새로 발급받은 PAT를 사용하여 설정합니다.
# 이렇게 하면 PAT가 코드에 직접 노출되지 않습니다.
# !git remote set-url origin https://Dlwndks-sudo:{GITHUB_PAT}@github.com/Dlwndks-sudo/DeepLearningProject-2025.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DeepLearningProject2025_Commit/DeepLearningProject-2025

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	git commit code.ipynb
# 	"\341\204\203\341\205\265\341\206\270\341\204\205\341\205\245\341\204\202\341\205\265\341\206\274 \341\204\221\341\205\263\341\204\205\341\205\251\341\204\214\341\205\246\341\206\250\341\204\220\341\205\263 \341\204\203\341\205\246\341\204\213\341\205\265\341\204\220\341\205\245 \341\204\214\341\205\245\341\206\253\341\204\216\341\205\245\341\204\205\341\205\265 \341\204\217\341\205\251\341\204\203\341\205\263.ipnyb"
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# 모든 변경된 추적 파일들을 스테이징하고 커밋합니다.
# !git add '딥러닝 프로젝트 코드.ipynb'
# !git add '딥러닝 프로젝트 데이터 전처리 코드.ipynb'
# !git commit -m "Update"
# Out:
# fatal: pathspec '딥러닝 프로젝트 데이터 전처리 코드.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	git commit code.ipynb
# 	"\341\204\203\341\205\265\341\206\270\341\204\205\341\205\245\341\204\202\341\205\265\341\206\274 \341\204\221\341\205\263\341\204\205\341\205\251\341\204\214\341\205\246\341\206\250\341\204\220\341\205\263 \341\204\203\341\205\246\341\204\213\341\205\265\341\204\220\341\205\245 \341\204\214\341\205\245\341\206\253\341\204\216\341\205\245\341\204\205\341\205\265 \341\204\217\341\205\251\341\204\203\341\205\263.ipnyb"
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ### 1. 두 파일 모두 스테이징
# `git commit code.ipynb`와 `딥러닝 프로젝트 데이터 전처리 코드.ipnyb` 두 파일을 스테이징 영역에 추가합니다.

# %%
# 커밋이 성공하면 원격 저장소에 푸시합니다.
# !git push origin main
# Out:
# Everything up-to-date
